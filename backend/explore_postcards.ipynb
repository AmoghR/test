# %%
import pandas as pd
import matplotlib.pyplot as plt
POSTCARDS_PATH = "../data/data.json"
postcard_df = pd.read_json(POSTCARDS_PATH)

# %%
postcard_df.columns
# Out:
# Index(['id', 'name', 'origin_country', 'receiving_country', 'time', 'distance',
#        'date_sent', 'date_received', 'origin_region', 'receiving_region',
#        'origin_city', 'receiving_city', 'origin_iso', 'receiving_iso'],
#       dtype='str')

# %%
postcard_df['time'].plot.box()
plt.show()
